# %% [markdown]
# <a href="https://colab.research.google.com/github/annisaeka123/2341720131_ML_2025/blob/main/JS13/P3_JS13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 3

# %% [markdown]
# Praktikum 3 kali ini kita akan mencoba menggunakan Keras untuk Regresi, khususnya pada kasus Prediksi Harga Rumah.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Contoh dataset (buat dummy data)
data = pd.DataFrame({
    'luas': [50, 60, 70, 80, 90],
    'harga': [500, 600, 700, 800, 900]
})

X = data[['luas']]
y = data[['harga']]

# Normalisasi
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
model = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, epochs=100)

# Evaluasi
print("Prediksi:", model.predict(X_test))
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1.7256
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 1.7110
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.6966
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.6823
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.6682
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.6541
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.6401
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.6263
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.6126
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.5991
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 1.5857
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.5726
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.5595
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.5466
# Epoch 15/100
# ...

# %% [markdown]
# Tugas 4:
#
# - Ubah learning rate.
#
# - Bandingkan hasil loss.

# %% [markdown]
# Model 1 — Learning Rate Kecil (0.001)

# %%
# Contoh dataset (buat dummy data)
data = pd.DataFrame({
    'luas': [50, 60, 70, 80, 90],
    'harga': [500, 600, 700, 800, 900]
})

X = data[['luas']]
y = data[['harga']]

# Normalisasi
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# optimizer untuk ubah learning rate
optimizer1 = tf.keras.optimizers.Adam(learning_rate=0.001)

# Model
model1 = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1)
])

model1.compile(optimizer=optimizer1, loss='mse')
history1 = model1.fit(X_train, y_train, epochs=100, verbose=0)

loss1 = model1.evaluate(X_test, y_test, verbose=0)

# Evaluasi
print("Loss dengan LR=0.001:", loss1)
# Out:
# Loss dengan LR=0.001: 0.021641505882143974

# %% [markdown]
# Model 2 — Learning Rate Besar (0.01)

# %%
# Contoh dataset (buat dummy data)
data = pd.DataFrame({
    'luas': [50, 60, 70, 80, 90],
    'harga': [500, 600, 700, 800, 900]
})

X = data[['luas']]
y = data[['harga']]

# Normalisasi
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# optimizer untuk ubah learning rate
optimizer2 = tf.keras.optimizers.Adam(learning_rate=0.01)

# Model
model2 = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1)
])

model2.compile(optimizer=optimizer2, loss='mse')
history2 = model2.fit(X_train, y_train, epochs=100, verbose=0)

loss2 = model2.evaluate(X_test, y_test, verbose=0)

# Evaluasi
print("Loss dengan LR=0.01:", loss2)
# Out:
# Loss dengan LR=0.01: 0.0016082568326964974

# %% [markdown]
# Membandingkan Loss

# %%
import matplotlib.pyplot as plt

plt.plot(history1.history['loss'], label='LR 0.001')
plt.plot(history2.history['loss'], label='LR 0.01')
plt.legend()
plt.title("Perbandingan Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# Perbandingan Loss
#
#
# | Konfigurasi             | Loss Awal | Loss Akhir Epoch 100 | Kecepatan Belajar | Stabilitas              |
# | ----------------------- | --------- | -------------------- | ----------------- | ----------------------- |
# | **Awal (default Adam)** | 1.72      | **0.88**             | Lambat            | Stabil                  |
# | **LR 0.001**            | ~0.80     | **~0.19**            | Lambat            | Sangat stabil           |
# | **LR 0.01**             | ~0.11     | **mendekati 0**      | Sangat cepat      | Stabil setelah epoch 10 |

# %% [markdown]
# Praktikum berikut akan menggunakan data Boston untuk memprediksi harga rumah.

# %%
# MLP regresi (Keras)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error

# 1. Load (Boston Housing manual)
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep=r"\s+", skiprows=22, header=None)

X = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
y = raw_df.values[1::2, 2]

# 2. Preprocess
scaler = StandardScaler()
Xs = scaler.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(
    Xs, y, test_size=0.2, random_state=42
)

# 3. Build model MLP
model = Sequential([
    tf.keras.Input(shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(optimizer=Adam(1e-3), loss='mse', metrics=['mae'])

# 4. Train
h = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=200,
    batch_size=32,
    verbose=0
)

# 5. Plot
plt.figure(figsize=(10,4))

# MSE
plt.subplot(1, 2, 1)
plt.plot(h.history['loss'], label='train_loss')
plt.plot(h.history['val_loss'], label='val_loss')
plt.legend()
plt.title('MSE')

# MAE
plt.subplot(1, 2, 2)
plt.plot(h.history['mae'], label='train_mae')
plt.plot(h.history['val_mae'], label='val_mae')
plt.legend()
plt.title('MAE')

plt.show()

# 6. Evaluasi RMSE
pred = model.predict(X_val)
rmse = np.sqrt(mean_squared_error(y_val, pred))
print("RMSE:", rmse)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# RMSE: 3.333622932467119
