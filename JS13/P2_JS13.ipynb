# %% [markdown]
# <a href="https://colab.research.google.com/github/annisaeka123/2341720131_ML_2025/blob/main/JS13/P2_JS13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 2
#
# Pada praktikum ini kita akan menggunakan library Keras untuk menggunakan JST. Keras adalah API tingkat tinggi untuk membangun JST dengan mudah, sedangkan TensorFlow adalah framework yang mendukung Keras.

# %% [markdown]
# Langkah:
#
# 1. Import library.
#
# 2. Load dataset.
#
# 3. Bangun model.
#
# 4. Kompilasi dan latih model.
#
# 5. Evaluasi hasil.

# %% [markdown]
# Klasifikasi Data Iris
#
#
# konfigurasi menggunakan ReLU

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# One-hot encoding
encoder = OneHotEncoder(sparse_output=False)
y = encoder.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Bangun model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(4,)),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Kompilasi
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Latih model
model.fit(X_train, y_train, epochs=50, batch_size=8)

# Evaluasi
loss, acc = model.evaluate(X_test, y_test)
print(f"Akurasi: {acc}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4385 - loss: 1.1439
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5566 - loss: 1.0934
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4018 - loss: 1.0824
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2115 - loss: 1.0535
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3878 - loss: 1.0333
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6532 - loss: 0.9929
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6789 - loss: 0.9687
# Epoch 8/50
# ...

# %% [markdown]
# Tugas 2
#
# - Ubah jumlah neuron hidden layer.
#
# - Bandingkan akurasi dengan konfigurasi awal.

# %% [markdown]
# Neuron Ditambah (Lebih Besar)

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# One-hot encoding
encoder = OneHotEncoder(sparse_output=False)
y = encoder.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Bangun model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape=(4,)),
    tf.keras.layers.Dense(12, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Kompilasi
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Latih model
model.fit(X_train, y_train, epochs=50, batch_size=8)

# Evaluasi
loss, acc = model.evaluate(X_test, y_test)
print(f"Akurasi: {acc}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3314 - loss: 1.1690
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3085 - loss: 1.0988
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4185 - loss: 1.0189
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4761 - loss: 0.9855
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6578 - loss: 0.9563
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6759 - loss: 0.8964
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7191 - loss: 0.8463
# Epoch 8/50
# ...

# %% [markdown]
# Neuron Dikurangi (Lebih Kecil)

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# One-hot encoding
encoder = OneHotEncoder(sparse_output=False)
y = encoder.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Bangun model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(6, activation='relu', input_shape=(4,)),
    tf.keras.layers.Dense(4, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Kompilasi
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Latih model
model.fit(X_train, y_train, epochs=50, batch_size=8)

# Evaluasi
loss, acc = model.evaluate(X_test, y_test)
print(f"Akurasi: {acc}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3712 - loss: 1.1025
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3736 - loss: 1.1099
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4168 - loss: 1.0156
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3332 - loss: 1.0464
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3593 - loss: 1.0145
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3241 - loss: 1.0035
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3001 - loss: 0.9822
# Epoch 8/50
# ...

# %% [markdown]
# Struktur Simetris

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# One-hot encoding
encoder = OneHotEncoder(sparse_output=False)
y = encoder.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Bangun model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(8, activation='relu', input_shape=(4,)),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Kompilasi
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Latih model
model.fit(X_train, y_train, epochs=50, batch_size=8)

# Evaluasi
loss, acc = model.evaluate(X_test, y_test)
print(f"Akurasi: {acc}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5214 - loss: 2.7019
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6808 - loss: 2.3992
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6595 - loss: 1.9819
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7040 - loss: 1.3278
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7148 - loss: 0.9702
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7440 - loss: 0.8470
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5442 - loss: 0.8648
# Epoch 8/50
# ...

# %% [markdown]
# | Konfigurasi          | Akurasi | Perbandingan terhadap Konfigurasi Awal                                                    |
# | -------------------- | ------- | ----------------------------------------------------------------------------------------- |
# | **Awal**             | **0.9667** | — (baseline)                                                                              |
# | **Neuron Ditambah**  | 0.9667  | Akurasinya sama dengan konfigurasi awal.                 |
# | **Neuron Dikurangi** | 0.7667  | Mengalami penurunan akurasi paling besar dari konfigurasi awal. |
# | **Neuron Simetris**  | 0.8999  | Penurunan akurasi dari konfigurasi awal tapi tidak sebesar penurunan neuron dikurangi.     |

# %% [markdown]
# Pada pengujian model, konfigurasi awal menghasilkan akurasi sebesar 1.0 dan dijadikan sebagai acuan (baseline). Setelah dilakukan perubahan jumlah neuron pada arsitektur jaringan, diperoleh hasil sebagai berikut:
#
# - Konfigurasi neuron ditambah memberikan akurasi 0.9667, atau mengalami penurunan sekitar 3.33% dibandingkan konfigurasi awal.
#
# - Konfigurasi neuron dikurangi menghasilkan akurasi 0.7667, yang merupakan penurunan terbesar, yaitu sekitar 23.33% dari konfigurasi awal. Hal ini menunjukkan bahwa pengurangan jumlah neuron mengurangi kapasitas model secara signifikan.
#
# - Konfigurasi neuron simetris memperoleh akurasi 0.9667, dengan penurunan yang sama seperti konfigurasi penambahan neuron, yaitu sekitar 3.33% dibandingkan konfigurasi awal.
#
# Kesimpulannya konfigurasi awal memberikan performa terbaik dengan akurasi 1.0. Penambahan maupun penataan ulang jumlah neuron tidak meningkatkan akurasi, bahkan menghasilkan sedikit penurunan performa. Sementara itu, pengurangan jumlah neuron secara signifikan menurunkan akurasi model. Hal ini menunjukkan bahwa kapasitas neuron pada konfigurasi awal sudah cukup optimal untuk mempelajari pola pada dataset Iris, sehingga perubahan jumlah neuron tidak diperlukan.

# %% [markdown]
# Tugas 3
#
# - Bandingkan Sigmoid vs ReLU pada dataset Iris.
#
# - Catat perbedaan loss dan akurasi.

# %% [markdown]
# Konfigurasi awal menggunakan ReLU

# %% [markdown]
# Jika menggunakan Sigmoid

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# One-hot encoding
encoder = OneHotEncoder(sparse_output=False)
y = encoder.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Bangun model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='sigmoid'),
    tf.keras.layers.Dense(8, activation='sigmoid'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Kompilasi
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Latih model
model.fit(X_train, y_train, epochs=50, batch_size=8)

# Evaluasi
loss, acc = model.evaluate(X_test, y_test)
print(f"Akurasi: {acc}")
# Out:
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2600 - loss: 1.2208
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3047 - loss: 1.1541
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2699 - loss: 1.1573
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3111 - loss: 1.1152
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3474 - loss: 1.1004
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3823 - loss: 1.0917
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2804 - loss: 1.1173
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3700 - loss: 1.0867
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3671 - loss: 1.0868
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3789 - loss: 1.0804
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3096 - loss: 1.0836
# Epoch 12/50
# ...

# %% [markdown]
# Akurasi Akhir
#
# | Konfigurasi | Akurasi Akhir | Keterangan                              |
# | ----------- | ------------- | --------------------------------------- |
# | **ReLU**    | **0.9667**    | Sangat tinggi, mendekati 1.0            |
# | **Sigmoid** | **0.7333**    | Lebih rendah, performa turun signifikan |

# %% [markdown]
# Perbandingan Loss
#
# | Sisi Perbandingan         | ReLU                   | Sigmoid                                    |
# | ------------------------- | ---------------------- | ------------------------------------------ |
# | **Loss awal (Epoch 1)**   | 1.1439                 | 1.2208                                     |
# | **Loss akhir (Epoch 50)** | **0.2924**             | **0.6356**                                 |
# | **Penurunan Loss**        | Turun besar dan stabil | Turun tetapi lebih lambat dan tidak stabil |

# %% [markdown]
# Kesimpulan Perbandingan
#
# Penggunaan fungsi aktivasi ReLU memberikan performa jauh lebih baik dibandingkan Sigmoid, baik dari sisi akurasi maupun penurunan loss. ReLU dapat belajar lebih cepat, stabil, dan menghasilkan akurasi tinggi pada dataset Iris. Sebaliknya, Sigmoid mengalami penurunan performa karena gradient mengecil, sehingga akurasi akhir jauh lebih rendah.
