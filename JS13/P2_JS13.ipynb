# %% [markdown]
# <a href="https://colab.research.google.com/github/annisaeka123/2341720131_ML_2025/blob/main/JS13/P2_JS13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 2
#
# Pada praktikum ini kita akan menggunakan library Keras untuk menggunakan JST. Keras adalah API tingkat tinggi untuk membangun JST dengan mudah, sedangkan TensorFlow adalah framework yang mendukung Keras.

# %% [markdown]
# Langkah:
#
# 1. Import library.
#
# 2. Load dataset.
#
# 3. Bangun model.
#
# 4. Kompilasi dan latih model.
#
# 5. Evaluasi hasil.

# %% [markdown]
# Klasifikasi Data Iris
#
#
# konfigurasi menggunakan ReLU

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# One-hot encoding
encoder = OneHotEncoder(sparse_output=False)
y = encoder.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Bangun model
model = tf.keras.Sequential([
    tf.keras.Input(shape=(4,)),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Kompilasi
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Latih model
model.fit(X_train, y_train, epochs=50, batch_size=8)

# Evaluasi
loss, acc = model.evaluate(X_test, y_test)
print(f"Akurasi: {acc}")
# Out:
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6421 - loss: 1.4825
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6814 - loss: 1.2127
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6935 - loss: 1.0848
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6986 - loss: 1.0261
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7102 - loss: 0.9595
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7017 - loss: 0.9379
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6702 - loss: 0.9382
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6447 - loss: 0.9235
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7369 - loss: 0.8324
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6872 - loss: 0.8448
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6772 - loss: 0.8294
# Epoch 12/50
# ...

# %% [markdown]
# Tugas 2
#
# - Ubah jumlah neuron hidden layer.
#
# - Bandingkan akurasi dengan konfigurasi awal.

# %% [markdown]
# Neuron Ditambah (Lebih Besar)

# %%
# Load dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# One-hot encoding
encoder = OneHotEncoder(sparse_output=False)
y = encoder.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Bangun model
model = tf.keras.Sequential([
    tf.keras.Input(shape=(4,)),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(12, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Kompilasi
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Latih model
model.fit(X_train, y_train, epochs=50, batch_size=8)

# Evaluasi
loss, acc = model.evaluate(X_test, y_test)
print(f"Akurasi: {acc}")
# Out:
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2346 - loss: 1.2126
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2969 - loss: 0.9491
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3302 - loss: 0.8866
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6226 - loss: 0.8189
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6540 - loss: 0.7660
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7053 - loss: 0.7257
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7139 - loss: 0.6976
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6868 - loss: 0.6690
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6956 - loss: 0.6433
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7813 - loss: 0.6027
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8054 - loss: 0.5905
# Epoch 12/50
# ...

# %% [markdown]
# Neuron Dikurangi (Lebih Kecil)

# %%
# Load dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# One-hot encoding
encoder = OneHotEncoder(sparse_output=False)
y = encoder.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Bangun model
model = tf.keras.Sequential([
    tf.keras.Input(shape=(4,)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(4, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Kompilasi
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Latih model
model.fit(X_train, y_train, epochs=50, batch_size=8)

# Evaluasi
loss, acc = model.evaluate(X_test, y_test)
print(f"Akurasi: {acc}")
# Out:
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3139 - loss: 1.3589
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3632 - loss: 1.1959
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4343 - loss: 1.1444
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4806 - loss: 1.0818
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5100 - loss: 1.0269
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4807 - loss: 1.0112
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4727 - loss: 0.9851
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5661 - loss: 0.8915
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4532 - loss: 0.9167
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6312 - loss: 0.8838
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6360 - loss: 0.8698
# Epoch 12/50
# ...

# %% [markdown]
# Struktur Simetris

# %%
# Load dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# One-hot encoding
encoder = OneHotEncoder(sparse_output=False)
y = encoder.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Bangun model
model = tf.keras.Sequential([
    tf.keras.Input(shape=(4,)),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Kompilasi
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Latih model
model.fit(X_train, y_train, epochs=50, batch_size=8)

# Evaluasi
loss, acc = model.evaluate(X_test, y_test)
print(f"Akurasi: {acc}")
# Out:
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2703 - loss: 1.5835
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3322 - loss: 1.2261
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2692 - loss: 1.3931
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2715 - loss: 1.1895
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3145 - loss: 1.0764
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3243 - loss: 1.0512
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3330 - loss: 0.9655
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3925 - loss: 0.9062
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6514 - loss: 0.8562
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7504 - loss: 0.8080
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7931 - loss: 0.7561
# Epoch 12/50
# ...

# %% [markdown]
# Konfigurasi awal menghasilkan akurasi:
# 0.8333333134651184
#
# Setelah dilakukan percobaan dengan beberapa variasi jumlah neuron, diperoleh hasil sebagai berikut:
#
# 1. Neuron Ditambah
#
# Akurasi: 0.9333333373069763
#
# - Peningkatan akurasi dibanding konfigurasi awal.
# - Penambahan jumlah neuron membuat model mampu menangkap pola lebih kompleks.
#
#
# 2. Neuron Dikurangi
#
# Akurasi: 1.0
# - Hasil paling tinggi dari seluruh eksperimen.
# - Menunjukkan bahwa pada dataset sederhana seperti Iris, model yang lebih kecil justru dapat bekerja lebih optimal karena tidak overfitting.
#
# 3. Neuron Simetris
#
# Akurasi: 0.9666666388511658
# - Lebih baik dari konfigurasi awal.
# - Struktur simetris cenderung stabil dan seimbang dalam pembelajaran.

# %% [markdown]
# Kesimpulan Perbandingan
#
# Jika dibandingkan dengan konfigurasi awal (0.8333):
#
# - Semua konfigurasi mengalami peningkatan akurasi.
#
# - Konfigurasi “neuron dikurangi” memberikan akurasi terbaik (1.0).
#
# - Ini menunjukkan bahwa model sederhana bisa lebih efektif untuk dataset kecil seperti Iris dan mengurangi risiko overfitting.

# %% [markdown]
# Tugas 3
#
# - Bandingkan Sigmoid vs ReLU pada dataset Iris.
#
# - Catat perbedaan loss dan akurasi.

# %% [markdown]
# Konfigurasi menggunakan Sigmoid

# %%
# Load dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# One-hot encoding
encoder = OneHotEncoder(sparse_output=False)
y = encoder.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Bangun model
model = tf.keras.Sequential([
    tf.keras.Input(shape=(4,)),
    tf.keras.layers.Dense(10, activation='sigmoid'),
    tf.keras.layers.Dense(8, activation='sigmoid'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Kompilasi
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Latih model
model.fit(X_train, y_train, epochs=50, batch_size=8)

# Evaluasi
loss, acc = model.evaluate(X_test, y_test)
print(f"Akurasi: {acc}")
# Out:
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3357 - loss: 1.2573
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3188 - loss: 1.2086
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3239 - loss: 1.1947
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3165 - loss: 1.1297
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3370 - loss: 1.1345
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3898 - loss: 1.0831
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4174 - loss: 1.0647
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3374 - loss: 1.1102
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3398 - loss: 1.0800
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4061 - loss: 1.0513
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3087 - loss: 1.0766
# Epoch 12/50
# ...

# %% [markdown]
# | Aspek                        | ReLU       | Sigmoid    | Perbedaan                             |
# | ---------------------------- | ---------- | ---------- | ------------------------------------- |
# | **Loss Awal**                | 1.48       | 1.25       | Sigmoid sedikit lebih rendah di awal  |
# | **Loss Akhir (training)**    | 0.39       | 0.59       | ReLU jauh lebih rendah (lebih stabil) |
# | **Akurasi Akhir (training)** | 0.90       | 0.83       | ReLU lebih tinggi                     |
# | **Loss Testing**             | 0.4463     | 0.6170     | ReLU lebih kecil                      |
# | **Akurasi Testing**          | **0.8333** | **0.7000** | ReLU menang signifikan                |

# %% [markdown]
# Kesimpulan
#
# ReLU memberikan performa yang lebih baik dibanding Sigmoid, baik dari sisi kecepatan konvergensi, penurunan loss, maupun akurasi akhir.
#
# Sigmoid kurang efektif pada hidden layer karena rawan vanishing gradient, sehingga model sulit mencapai akurasi tinggi.
